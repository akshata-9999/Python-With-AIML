# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-9999/Python-With-AIML/blob/Core-Python/09List_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=[9,26,1,13,45,30]
print(n)
print(type(n))
# Out:
# [9, 26, 1, 13, 45, 30]
# <class 'list'>

# %%
n.append(15)
print(n)
# Out:
# [9, 26, 1, 13, 45, 30, 15]

# %%
nm=[]
print(type(nm))
nm.append("java")
nm.append("spring")
nm.append("python")
nm.append("pandas")
print(nm)
# Out:
# <class 'list'>
# ['java', 'spring', 'python', 'pandas']

# %%
nm.insert(2,"mongodb")
print(nm)
# Out:
# ['java', 'spring', 'mongodb', 'python', 'pandas']

# %%
nm.remove("python")
print(nm)
# nm.clear()
# Out:
# ['java', 'spring', 'mongodb', 'pandas']

# %%
cloud=['azure','aws','gcp']
nm.extend(cloud)
print(nm)
# Out:
# ['java', 'spring', 'mongodb', 'pandas', 'azure', 'aws', 'gcp']

# %%
print(nm[3])
# Out:
# pandas

# %%
print(nm)
# Out:
# ['java', 'spring', 'mongodb', 'pandas', 'azure', 'aws', 'gcp']

# %%
#retrive and remove last element from list
print(nm.pop())
# Out:
# gcp

# %%
print(nm)
# Out:
# ['java', 'spring', 'mongodb', 'pandas', 'azure', 'aws']

# %%
#nm.sort()
nm.sort(reverse=True)
print(nm)
# Out:
# ['spring', 'pandas', 'mongodb', 'java', 'azure', 'aws']

# %%
comp=['microsoft','volkswagen','samsung','dell','hp']
comp.reverse()
print(comp)
# Out:
# ['hp', 'dell', 'samsung', 'volkswagen', 'microsoft']

# %%
for cnm in comp:
  print(cnm.capitalize())
# Out:
# Hp
# Dell
# Samsung
# Volkswagen
# Microsoft

# %%
lst=[9,'praffull',13.26,True]
print(lst)

for item in lst:
  print(type(item))
# Out:
# [9, 'praffull', 13.26, True]
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
