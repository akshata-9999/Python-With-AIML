# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-9999/Python-With-AIML/blob/Core-Python/03Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Arithmetic Operators**

# %%
x=9
y=13

# arithmetic operators demo
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# floor division
print(y//x)
#modulus
print(y%x)
print(27%4)
#power
print(7**2)
print(2**3)
# Out:
# 22
# -4
# 117
# 0.6923076923076923
# 1
# 4
# 3
# 49
# 8

# %% [markdown]
# **Relational Operators**

# %%
a=5

print(a==3)
print(a==5)
password="chelsea"
print(password=="liverpool")

x=10
print(x>15)
print(x<15)
print(x<=10)
print(x>=15)
print(x!=7)
# Out:
# False
# True
# False
# False
# True
# True
# False
# True

# %% [markdown]
# **Assignment Operators**

# %%
x=9
x+=3    # x=x+3
x-=2
x*=5
x/=2
x//=5
x%=2
print(x)
# Out:
# 1.0

# %% [markdown]
# **Logical Operators**

# %%
print(10>5)
print(7<5)

print(10>5 and 7<5)
print(10>5 or 7<5)
print(not 9>13)
# Out:
# True
# False
# False
# True
# True

# %% [markdown]
# **Membership operators**

# %%
print('s' in 'Akshata')
print('s' not in 'Akshata')

lst=['soham','praffull','sharayu','tejas','vijay']
print('megha' in lst)
# Out:
# True
# False
# False

# %% [markdown]
# **Ternary Operator**

# %%
marks=25
result='pass' if marks>=35 else "fail"
print(result)
# Out:
# fail
