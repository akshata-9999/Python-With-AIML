# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-9999/Python-With-AIML/blob/Core-Python/02InputOutput.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Input output in Python**

# %%
nm=input('Enter your name ')
# Out:
# Enter your name Akshata

# %%
print(f'user name is {nm}')
# Out:
# user name is Akshata

# %%
n=int(input('Enter a number '))
sq=n*n
print(f"square of {n} is {sq}")
# Out:
# Enter a number 6
# square of 6 is 36

# %%
x=float(input('Enter first number '))
y=float(input('Enter second number '))
z=x+y
print(f"sum of {x} and {y} is {z}")
# Out:
# Enter first number 6
# Enter second number 5
# sum of 6.0 and 5.0 is 11.0

# %%
custnm=input('Enter customer name ')
amount=float(input('Enter purchase amount '))
discount=amount*10/100
net=amount-discount
print(f'Customer Name : {custnm}')
print(f'Purchase amount : {amount}')
print(f'Discount : {discount}')
print(f'Net Bill : {net}')
# Out:
# Enter customer name Akshata Lad
# Enter purchase amount 15000
# Customer Name : Akshata Lad
# Purchase amount : 15000.0
# Discount : 1500.0
# Net Bill : 13500.0
