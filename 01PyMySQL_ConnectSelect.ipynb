# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /usr/local/lib/python3.12/dist-packages (1.1.2)

# %% [markdown]
# import the module in the code

# %%
import pymysql

# %% [markdown]
# Connect to MySQL database

# %%
connection=pymysql.connect(host='mysql-java-ladakshata2004-javaproject.c.aivencloud.com',port=11805,user='avnadmin',password='AVNS_GPpotT5gabbNgVfqYnh',database='akshatadb')
print('connected to cloud MySQL successfully')
# Out:
# connected to cloud MySQL successfully

# %% [markdown]
# connected to cloud MySQL successfully

# %%
cursor=connection.cursor()

# %%
cursor.execute("select * from Student")
data=cursor.fetchall()
print(data)
# Out:
# ((1, 'Alice Johnson', 'alice@example.com', '9876543210'), (2, 'Bob Smith', 'bob@example.com', '9123456780'), (3, 'Charlie Brown', 'charlie@example.com', '9988776655'), (4, 'Diana Prince', 'diana@example.com', '9001122334'), (5, 'Ethan Hunt', 'ethan@example.com', '9112233445'), (6, 'Fiona White', 'fiona@example.com', '9223344556'), (7, 'George Miller', 'george@example.com', '9334455667'), (8, 'Hannah Scott', 'hannah@example.com', '9445566778'), (9, 'Ian Clark', 'ian@example.com', '9556677889'), (10, 'Julia Davis', 'julia@example.com', '9667788990'))

# %%
cursor.execute("select * from employees")
data=cursor.fetchall()
print(data)
# Out:
# ((1001, 'John Smith', 'Marketing', 'Manager', 'New York', 56100.0), (1002, 'Jane Doe', 'Development', 'Senior Developer', 'San Francisco', 81500.0), (1003, 'Alice Johnson', 'Sales', 'Sales Executive', 'Chicago', 51000.0), (1004, 'Bob Brown', 'Marketing', 'Assistant Manager', 'Los Angeles', 53100.0), (1005, 'Emily Davis', 'Development', 'Software Engineer', 'Austin', 86500.0), (1006, 'Michael Wilson', 'Sales', 'Sales Representative', 'Miami', 54000.0), (1007, 'Sarah Lee', 'Marketing', 'Marketing Specialist', 'Boston', 61100.0), (1008, 'David Clark', 'Development', 'Backend Developer', 'Seattle', 83500.0), (1009, 'Laura King', 'Sales', 'Sales Associate', 'Dallas', 52000.0), (1010, 'James White', 'Marketing', 'Marketing Coordinator', 'Denver', 55100.0), (1011, 'Thomas Green', 'Development', 'DevOps Engineer', 'Atlanta', 84500.0), (1012, 'Jessica Hall', 'Sales', 'Sales Manager', 'Houston', 55000.0), (1013, 'Kevin Young', 'Marketing', 'Brand Manager', 'Chicago', 57100.0), (1014, 'Patricia Adams', 'Development', 'Project Manager', 'New York', 89500.0), (1015, 'Frank Miller', 'Sales', 'Customer Success Manager', 'Phoenix', 53000.0), (1016, 'Megan Scott', 'Marketing', 'Social Media Manager', 'San Francisco', 60100.0), (1017, 'Daniel Evans', 'Development', 'Frontend Developer', 'Boston', 85500.0), (1018, 'Rachel Turner', 'Sales', 'Sales Consultant', 'Los Angeles', 51000.0), (1019, 'Christopher Moore', 'Marketing', 'Advertising Specialist', 'Miami', 62100.0), (1020, 'Linda Harris', 'Development', 'QA Engineer', 'Dallas', 82500.0))

# %%
cursor.execute("select * from accounts")
data=cursor.fetchall()
print(data)
# Out:
# ((101, 'Saurabh Deshmukh', 'current', 103000.0), (103, 'Akshata Lad', 'ppf', 20000.0), (105, 'Akshata Mohite', 'fixed', 26000.0), (106, 'Saurabh Deshmukh', 'current', 19000.0), (107, 'Sakshi chavan', 'fixed', 5000.0), (991, 'ashwini maam', 'fixed', 260424.0), (992, 'sharayu', 'fixed', 210518.0), (993, 'praffull', 'current', 74300.0), (994, 'ajinkya kulkarni', 'ppf', 80000.0), (1001, 'charles leclerc', 'saving', 46000.0), (1002, 'maria sharapova', 'fixed', 23100.0), (1003, 'mitchell johnson', 'current', 14300.0), (1004, 'edan hazard', 'saving', 41300.0), (1005, 'robert lewandowski', 'saving', 21600.0), (1006, 'gabriel jesus', 'fixed', 37100.0), (1008, 'marcos alonso', 'saving', 33900.0), (1009, 'david luiz', 'current', 27400.0), (1010, 'steve smith', 'fixed', 61150.0), (1012, 'zaheer khan', 'saving', 22570.0), (1013, 'antoine griezman', 'fixed', 37640.0), (1014, 'nasser hussain', 'saving', 53760.0), (1015, 'fernando alonso', 'saving', 67370.0), (1016, 'garry cahill', 'current', 38550.0), (1017, 'thibaut courtois', 'fixed', 97550.0), (1018, 'cesar azpilicueta', 'current', 81716.0), (1019, 'cesc fabregas', 'current', 81716.0), (1020, 'ngolo kante', 'fixed', 55871.0), (1021, 'james anderson', 'current', 62228.0), (1022, 'ollie pope', 'saving', 75961.0), (1023, 'moin ali', 'current', 25551.0), (1024, 'sam curran', 'ppf', 63558.0), (1025, 'andreas christensen', 'saving', 68523.0), (1026, 'alvaro morata', 'saving', 96995.0), (1027, 'liam livingstone', 'current', 48668.0), (1028, 'mark wood', 'fixed', 75442.0), (1029, 'mohamed salah', 'saving', 83229.0), (1030, 'sadio mane', 'ppf', 45889.0), (1031, 'roberto firmino', 'fixed', 96321.0), (1032, 'alex oxlade chamberlain', 'current', 57449.0), (1033, 'alexandre lacazette', 'saving', 36227.0), (1034, 'raheem sterling', 'fixed', 62994.0), (1035, 'harry kane', 'current', 77751.0), (1036, 'carlos sainz', 'fixed', 96637.0), (1037, 'hugo lloris', 'saving', 84552.0), (1038, 'bill gates', 'current', 92119.0), (1039, 'amir khan', 'saving', 66554.0), (1040, 'adil rashid', 'ppf', 39870.0), (1041, 'chris jordan', 'saving', 55400.0), (1042, 'jason roy', 'saving', 29750.0), (1043, 'chris woakes', 'ppf', 50000.0), (1044, 'alex hales', 'saving', 38540.0), (1045, 'dawid malan', 'saving', 62100.0), (1046, 'ben stokes', 'saving', 57500.0), (1047, 'joe root', 'ppf', 125000.0), (1048, 'isa guha', 'saving', 72300.0), (1049, 'ravi shastri', 'saving', 55040.0), (1050, 'harsha bhogle', 'saving', 87980.0), (1051, 'lando norris', 'ppf', 75000.0), (1052, 'Sanjay Lad', 'fixed', 100000.0), (1053, 'Sujata Lad', 'ppf', 99500.0), (1054, 'Saurabh Deshmukh', 'current', 99000.0), (1234, 'Akshata Mohite', 'fixed', 9000.0))

# %%
connection.close()
