# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-9999/Python-With-AIML/blob/Core-Python/06whileloops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=1

while n<=5:
  print(n)
  n+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n=1

while n!=0:
  n=int(input('Enter a number (0 to stop) : '))
  sq=n*n
  print(f'square of {n} is {sq}')
# Out:
# Enter a number (0 to stop) : 5
# square of 5 is 25
# Enter a number (0 to stop) : 0
# square of 0 is 0

# %%
nm=''

while nm!='stop':
  nm=input('Enter name : ')
  if nm!='stop':
     print(f'welcome {nm} to python')
# Out:
# Enter name : Akshata
# welcome Akshata to python
# Enter name : Saurabh
# welcome Saurabh to python
# Enter name : stop

# %%
n=1

while True:
  if n==5:
    break
  print(n)
  n+=1
# Out:
# 1
# 2
# 3
# 4

# %%
i=0

while i<5:
  i+=1
  if i==3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
