# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-9999/Python-With-AIML/blob/MySQLProgramming/06PyMySQL_Searching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2

# %%
import pymysql

# %%
connection=pymysql.connect(host='mysql-java-ladakshata2004-javaproject.c.aivencloud.com',port=11805,user='avnadmin',password='AVNS_GPpotT5gabbNgVfqYnh',database='akshatadb')
print('connected to cloud MySQL successfully')
# Out:
# connected to cloud MySQL successfully

# %%
cursor=connection.cursor()

# %%
no=int(input('Enter account number to search : '))
cursor.execute(f"select * from accounts where accno={no}")
data=cursor.fetchone()
if data:
  print(data)
else:
  print('account does not exist')
# Out:
# Enter account number to search : 1234
# (1234, 'Akshata Mohite', 'fixed', 9000.0)

# %%
typ=input('Enter account type : ')
cursor.execute(f"select * from accounts where acctype='{typ}'")
data=cursor.fetchall()
print(data)
# Out:
# Enter account type : ppf
# ((103, 'Akshata Lad', 'ppf', 20000.0), (994, 'ajinkya kulkarni', 'ppf', 80000.0), (1024, 'sam curran', 'ppf', 63558.0), (1030, 'sadio mane', 'ppf', 45889.0), (1040, 'adil rashid', 'ppf', 39870.0), (1043, 'chris woakes', 'ppf', 50000.0), (1047, 'joe root', 'ppf', 125000.0), (1051, 'lando norris', 'ppf', 75000.0), (1053, 'Sujata Lad', 'ppf', 99500.0))

# %%
typ=input('Enter account type : ')
amt=float(input('Enter amount : '))
cursor.execute(f"select * from accounts where acctype='{typ}' and balance>{amt}")
data=cursor.fetchall()
print(data)
# Out:
# Enter account type : savings
# Enter amount : 2000
# ()

# %%
typ=input('Enter account type : ')
amt=float(input('Enter amount : '))
cursor.execute(f"select * from accounts where acctype='{typ}' and balance>{amt}")
data=cursor.fetchall()
print(data)
# Out:
# Enter account type : saving
# Enter amount : 55000
# ((1015, 'fernando alonso', 'saving', 67370.0), (1022, 'ollie pope', 'saving', 75961.0), (1025, 'andreas christensen', 'saving', 68523.0), (1026, 'alvaro morata', 'saving', 96995.0), (1029, 'mohamed salah', 'saving', 83229.0), (1037, 'hugo lloris', 'saving', 84552.0), (1039, 'amir khan', 'saving', 66554.0), (1041, 'chris jordan', 'saving', 55400.0), (1045, 'dawid malan', 'saving', 62100.0), (1046, 'ben stokes', 'saving', 57500.0), (1048, 'isa guha', 'saving', 72300.0), (1049, 'ravi shastri', 'saving', 55040.0), (1050, 'harsha bhogle', 'saving', 87980.0))

# %%
connection.close()
