# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-9999/Python-With-AIML/blob/Core-Python/04ifconditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Check Pass or Fail**

# %%
name=input('Enter name : ')
marks=int(input('Enter marks : '))
if marks>=35:
  print('Congratulations')
  print(f'{name} you are pass')
else:
  print('Sorry')
  print(f'{name} you are fail')
# Out:
# Enter name : Akshata Lad
# Enter marks : 55
# Congratulations
# Akshata Lad you are pass

# %% [markdown]
# **find out if the number is odd or even**

# %%
n=int(input('Enter a number : '))
if n%2==0:
  print('number is even')
else:
  print('number is odd')
# Out:
# Enter a number : 9
# number is odd

# %% [markdown]
# **Find out number is negative or positive**

# %%
n=int(input('Enter a number : '))
if n==0:
  print(f'{n} is a neutral number')
else:
  if n>0:
    print('number is positive')
  else:
    print('number is negative')
# Out:
# Enter a number : 9
# number is positive

# %% [markdown]
# **Check Password is correct or not**

# %%
password=input('Enter your password : ')
if password=='chelsea':
  print('welcome to python')
else:
  print('sorry password incorrect')
# Out:
# Enter your password : chelsea
# welcome to python

# %% [markdown]
# **Calculate discount on the perticular amount**

# %%
custnm=input('Enter customer name : ')
amount=float(input('Enter purchase amount : '))
if amount>20000:
  print('13% discount applied')
  discount=amount*13/100
else:
  print('9% discount applied')
  discount=amount*9/100

netbill=amount-discount
print(f'Customer Name : {custnm}')
print(f'Amount : {amount}')
print(f'Discount : {discount}')
print(f'Net Bill : {netbill}')
# Out:
# Enter customer name : Akshata Lad
# Enter purchase amount : 15000
# 9% discount applied
# Customer Name : Akshata Lad
# Amount : 15000.0
# Discount : 1350.0
# Net Bill : 13650.0
