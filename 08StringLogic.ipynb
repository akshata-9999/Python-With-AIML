# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-9999/Python-With-AIML/blob/Core-Python/08StringLogic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="python"
b="python"
print(id(a)==id(b))

c=a.upper()
print(id(a)==id(c))
# Out:
# True
# False

# %% [markdown]
# **Reverse the string**

# %%
s="sohamglobal"
rev=""

for ch in s:
  rev=ch+rev

print(rev)
# Out:
# labolgmahos

# %%
s="sohamglobal"
print(s[3])
print(s[-1])
# Out:
# a
# l

# %%
s="spider"
print(s[::-1])
# Out:
# redips

# %%
s="madam"
s1=s[::-1]

if s==s1:
  print("palindrome")
else:
  print("not a palindrome")
# Out:
# palindrome

# %%
s="technology is power"
vowels="aeiouAEIOU"
count=0

for ch in s:
  if ch in vowels:
    count+=1

print(f"number of vowels in the string are {count}")
# Out:
# number of vowels in the string are 6

# %%
s1="listen"
s2="silent"

print(sorted(s1))

if sorted(s1)==sorted(s2):
  print("anagram")
else:
  print("not anagram")
# Out:
# ['e', 'i', 'l', 'n', 's', 't']
# anagram
