# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-9999/Python-With-AIML/blob/Core-Python/01Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **My first notebook for testing online python**

# %%
a=9
b=13
c=a+b
print(f"sum of {a} and {b} is {c}")
# Out:
# sum of 9 and 13 is 22

# %%
x=5
print(f"square of {x} is {x*x}")
# Out:
# square of 5 is 25

# %%
name="Akshata"
print(f"Welcome {name} to the exciting world of python")
# Out:
# Welcome Akshata to the exciting world of python

# %%
x=45.72
y=33.87
z=x+y
print(f"sum is {z}")
print(type(z))
# Out:
# sum is 79.59
# <class 'float'>

# %% [markdown]
# **Thank You...**
