# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-9999/Python-With-AIML/blob/MySQLProgramming/05PyMySQL_Delete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.5 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
connection=pymysql.connect(host='mysql-java-ladakshata2004-javaproject.c.aivencloud.com',port=11805,user='avnadmin',password='AVNS_GPpotT5gabbNgVfqYnh',database='akshatadb')
print('connected to cloud MySQL successfully')
# Out:
# connected to cloud MySQL successfully

# %%
cursor=connection.cursor()

# %%
ano=int(input('Enter account number : '))
cnt=cursor.execute(f"delete from accounts where accno={ano}")
connection.commit()
if cnt>0:
  print('account closed successfully')
else:
  print("account not found")
# Out:
# Enter account number : 12345
# account not found
