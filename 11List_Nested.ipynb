# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-9999/Python-With-AIML/blob/Core-Python/11List_Nested.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst=['java','python','spring','pandas',['praffull','sharayu']]
print(lst)
# Out:
# ['java', 'python', 'spring', 'pandas', ['praffull', 'sharayu']]

# %%
lst.append('spark')
print(lst)
# Out:
# ['java', 'python', 'spring', 'pandas', ['praffull', 'sharayu'], 'spark']

# %%
lst[4].append('soham')
print(lst)
# Out:
# ['java', 'python', 'spring', 'pandas', ['praffull', 'sharayu', 'soham'], 'spark']

# %%
profiles=[
    ['praffull','sharayu','tejas'],
    ['core java','python','spring boot'],
    ['9 june','13 january','1 january'],
    [23,10,5],
    ['london','dubai','pune']
]

#print(profiles)
for items in profiles:
  print(items)
# Out:
# ['praffull', 'sharayu', 'tejas']
# ['core java', 'python', 'spring boot']
# ['9 june', '13 january', '1 january']
# [23, 10, 5]
# ['london', 'dubai', 'pune']

# %%
print(profiles[1][2])
# Out:
# spring boot
